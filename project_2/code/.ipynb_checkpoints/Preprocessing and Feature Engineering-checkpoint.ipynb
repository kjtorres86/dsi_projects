# %% [markdown]
# ## Pre-processing
# - One-hot encode categorical variables.
# - Train/test split your data.
# - Scale your data.
# - Consider using automated feature selection.

# %%
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pylab as plt
import pandas as pd

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import Ridge, RidgeCV ,Lasso, LassoCV, ElasticNet, ElasticNetCV

# %matplotlib inline
# Out:
# /Users/johnsmith/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
train_df = pd.read_csv('../datasets/train_df.csv', index_col=0)
test_df = pd.read_csv('../datasets/test_df.csv', index_col=0)

# %%
pd.options.display.max_rows = 200

# %%
pd.options.display.max_info_rows = 200

# %%
pd.options.display.max_columns = 200

# %%
pd.options.display.max_info_columns = 200

# %%
train_df.shape
# Out:
# (2049, 81)

# %%
test_df.shape
# Out:
# (878, 80)

# %%
train_df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
test_df.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2049 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Id               int64
#  1   PID              int64
#  2   MS SubClass      int64
#  3   MS Zoning        object
#  4   Lot Frontage     float64
#  5   Lot Area         int64
#  6   Street           object
#  7   Alley            object
#  8   Lot Shape        object
#  9   Land Contour     object
#  10  Utilities        object
#  11  Lot Config       object
#  12  Land Slope       object
#  13  Neighborhood     object
#  14  Condition 1      object
#  15  Condition 2      object
#  16  Bldg Type        object
#  17  House Style      object
#  18  Overall Qual     int64
#  19  Overall Cond     int64
#  20  Year Built       int64
#  21  Year Remod/Add   int64
#  22  Roof Style       object
#  23  Roof Matl        object
#  24  Exterior 1st     object
#  25  Exterior 2nd     object
# ...

# %% [markdown]
# features shortlist for categorical, 'Lot Shape' 'Neighborhood' 'Condition 1' 'Condition 2' 'Roof Matl' 'Bsmt Qual' 'Bsmt Exposure' 'Kitchen Qual' 'Functional' 'Fireplace Qu'  'Overall Qual' 'Garage Cars' 'Bsmt Full Bath'
# 'Full Bath' 'TotRms AbvGrd' 'Exter Qual' 'Exter Cond'
#
#
# #combine full bathrooms
# #see what can be done about condition 1 and 2 since it is the same ordinal scale, dropping condition 2 since it has low variance that we can try our model on and it is highly collinear with Condition 1.
# #might also drop Roof Matl since the distribution is very skewed towards one material.
# #We can add 'Gr Liv Area', 'Garage Area', 'Total Bsmt SF', '1st Flr SF ' to our initial shortlist for features. 'Mas Vnr Area' has too many null values for it to be used as a reliable predictor.

# %%
cat_features_encoded = train_df[['Lot Shape', 
                               'Neighborhood', 
                               'Condition 1',
                               'Bsmt Qual',
                               'Bsmt Exposure',
                               'Kitchen Qual',
                               'Functional',
                               'Fireplace Qu', 
                               'Overall Qual',
                               'Garage Cars',
                               'Bsmt Full Bath',
                               'Full Bath',
                               'TotRms AbvGrd',
                               'Exter Qual',
                               'Exter Cond']]
cat_features_encoded.head()
# Out:
#   Lot Shape Neighborhood Condition 1 Bsmt Qual Bsmt Exposure Kitchen Qual  \
# 0       IR1       Sawyer        RRAe        TA            No           Gd
# 1       IR1      SawyerW        Norm        Gd            No           Gd
# 2       Reg        NAmes        Norm        TA            No           Gd
# 3       Reg       Timber        Norm        Gd            No           TA
# 4       IR1      SawyerW        Norm        Fa            No           TA
#
#   Functional Fireplace Qu  Overall Qual  Garage Cars  Bsmt Full Bath  \
# 0        Typ          NaN             6            2               0
# 1        Typ           TA             7            2               1
# 2        Typ          NaN             5            1               1
# 3        Typ          NaN             5            2               0
# 4        Typ          NaN             6            2               0
#
#    Full Bath  TotRms AbvGrd Exter Qual Exter Cond
# 0          2              6         Gd         TA
# ...

# %%
cat_features_encoded_test = test_df[['Lot Shape', 
                               'Neighborhood', 
                               'Condition 1',
                               'Bsmt Qual',
                               'Bsmt Exposure',
                               'Kitchen Qual',
                               'Functional',
                               'Fireplace Qu', 
                               'Overall Qual',
                               'Garage Cars',
                               'Bsmt Full Bath',
                               'Full Bath',
                               'TotRms AbvGrd',
                               'Exter Qual',
                               'Exter Cond']]
cat_features_encoded_test.head()
# Out:
#   Lot Shape Neighborhood Condition 1 Bsmt Qual Bsmt Exposure Kitchen Qual  \
# 0       Reg      OldTown        Norm        Fa            No           Fa
# 1       IR1       Sawyer        Norm        Gd            No           TA
# 2       IR1      Gilbert        Norm        Gd            Av           Gd
# 3       Reg      OldTown        Norm        TA            No           TA
# 4       IR1        NAmes        Norm        Gd            No           TA
#
#   Functional Fireplace Qu  Overall Qual  Garage Cars  Bsmt Full Bath  \
# 0        Typ          NaN             6            1               0
# 1        Typ          NaN             5            2               0
# 2        Typ           Gd             7            2               1
# 3        Typ          NaN             5            2               0
# 4        Typ           Gd             6            2               1
#
#    Full Bath  TotRms AbvGrd Exter Qual Exter Cond
# 0          2              9         TA         Fa
# ...

# %%
cat_features_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2049 entries, 0 to 2050
# Data columns (total 15 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Lot Shape       object
#  1   Neighborhood    object
#  2   Condition 1     object
#  3   Bsmt Qual       object
#  4   Bsmt Exposure   object
#  5   Kitchen Qual    object
#  6   Functional      object
#  7   Fireplace Qu    object
#  8   Overall Qual    int64
#  9   Garage Cars     int64
#  10  Bsmt Full Bath  int64
#  11  Full Bath       int64
#  12  TotRms AbvGrd   int64
#  13  Exter Qual      object
#  14  Exter Cond      object
# dtypes: int64(5), object(10)
# memory usage: 256.1+ KB

# %%
cat_features_encoded_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 878 entries, 0 to 878
# Data columns (total 15 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Lot Shape       object
#  1   Neighborhood    object
#  2   Condition 1     object
#  3   Bsmt Qual       object
#  4   Bsmt Exposure   object
#  5   Kitchen Qual    object
#  6   Functional      object
#  7   Fireplace Qu    object
#  8   Overall Qual    int64
#  9   Garage Cars     int64
#  10  Bsmt Full Bath  int64
#  11  Full Bath       int64
#  12  TotRms AbvGrd   int64
#  13  Exter Qual      object
#  14  Exter Cond      object
# dtypes: int64(5), object(10)
# memory usage: 109.8+ KB

# %%
cat_features_encoded = pd.get_dummies(cat_features_encoded)

# %%
cat_features_encoded_test = pd.get_dummies(cat_features_encoded_test)

# %%
cat_features_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2049 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Overall Qual          int64
#  1   Garage Cars           int64
#  2   Bsmt Full Bath        int64
#  3   Full Bath             int64
#  4   TotRms AbvGrd         int64
#  5   Lot Shape_IR1         uint8
#  6   Lot Shape_IR2         uint8
#  7   Lot Shape_IR3         uint8
#  8   Lot Shape_Reg         uint8
#  9   Neighborhood_Blmngtn  uint8
#  10  Neighborhood_Blueste  uint8
#  11  Neighborhood_BrDale   uint8
#  12  Neighborhood_BrkSide  uint8
#  13  Neighborhood_ClearCr  uint8
#  14  Neighborhood_CollgCr  uint8
#  15  Neighborhood_Crawfor  uint8
#  16  Neighborhood_Edwards  uint8
#  17  Neighborhood_Gilbert  uint8
#  18  Neighborhood_Greens   uint8
#  19  Neighborhood_GrnHill  uint8
#  20  Neighborhood_IDOTRR   uint8
#  21  Neighborhood_Landmrk  uint8
#  22  Neighborhood_MeadowV  uint8
# ...

# %%
cat_features_encoded.corr('spearman')
# Out:
#                       Overall Qual  Garage Cars  Bsmt Full Bath  Full Bath  \
# Overall Qual              1.000000     0.601459        0.156788   0.549825
# Garage Cars               0.601459     1.000000        0.169010   0.518843
# Bsmt Full Bath            0.156788     0.169010        1.000000  -0.022583
# Full Bath                 0.549825     0.518843       -0.022583   1.000000
# TotRms AbvGrd             0.373280     0.402418       -0.061031   0.534696
# Lot Shape_IR1             0.238935     0.232276        0.092588   0.187395
# Lot Shape_IR2             0.079379     0.076088        0.032247   0.066642
# Lot Shape_IR3             0.020645     0.022387       -0.019994   0.041040
# Lot Shape_Reg            -0.263594    -0.256204       -0.098805  -0.211610
# Neighborhood_Blmngtn      0.093999     0.078652       -0.030527   0.073414
# Neighborhood_Blueste      0.024421     0.018266       -0.009321  -0.024615
# ...

# %%
plt.figure(figsize=(16,12))

mask = np.zeros_like(cat_features_encoded.corr('spearman'))
#mask 
mask[np.triu_indices_from(mask)] = True

with sns.axes_style("white"):
    ax = sns.heatmap(cat_features_encoded.corr('spearman'),mask=mask, annot=True) 
    ax.set_title("Heatmap of correlation between categorical values", fontsize=25);

# %%
#dropping ordinal columns that already exists in train dataset
cat_features_encoded.drop(['Overall Qual',
                           'Garage Cars',
                           'Full Bath',
                          'TotRms AbvGrd',
                          'Bsmt Full Bath'], axis=1, inplace=True)

# %%
cat_features_encoded_test.drop(['Overall Qual',
                           'Garage Cars',
                           'Full Bath',
                          'TotRms AbvGrd',
                          'Bsmt Full Bath'], axis=1, inplace=True)

# %%
#joining the dummies with training dataset for analysis. should end up with 145 columns
train_df = pd.concat([train_df, cat_features_encoded], axis=1)

# %%
test_df = pd.concat([test_df, cat_features_encoded_test], axis=1)

# %%
train_df.shape
# Out:
# (2049, 157)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2049 entries, 0 to 2050
# Data columns (total 157 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Id                    int64
#  1   PID                   int64
#  2   MS SubClass           int64
#  3   MS Zoning             object
#  4   Lot Frontage          float64
#  5   Lot Area              int64
#  6   Street                object
#  7   Alley                 object
#  8   Lot Shape             object
#  9   Land Contour          object
#  10  Utilities             object
#  11  Lot Config            object
#  12  Land Slope            object
#  13  Neighborhood          object
#  14  Condition 1           object
#  15  Condition 2           object
#  16  Bldg Type             object
#  17  House Style           object
#  18  Overall Qual          int64
#  19  Overall Cond          int64
#  20  Year Built            int64
#  21  Year Remod/Add        int64
# ...

# %%
train_df.drop(['Lot Shape', 
               'Neighborhood',
               'Condition 1',
               'Bsmt Qual',
               'Bsmt Exposure',
               'Kitchen Qual',
               'Functional',
               'Fireplace Qu',
               'Exter Qual',
               'Exter Cond'], axis=1, inplace=True)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2049 entries, 0 to 2050
# Data columns (total 147 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Id                    int64
#  1   PID                   int64
#  2   MS SubClass           int64
#  3   MS Zoning             object
#  4   Lot Frontage          float64
#  5   Lot Area              int64
#  6   Street                object
#  7   Alley                 object
#  8   Land Contour          object
#  9   Utilities             object
#  10  Lot Config            object
#  11  Land Slope            object
#  12  Condition 2           object
#  13  Bldg Type             object
#  14  House Style           object
#  15  Overall Qual          int64
#  16  Overall Cond          int64
#  17  Year Built            int64
#  18  Year Remod/Add        int64
#  19  Roof Style            object
#  20  Roof Matl             object
#  21  Exterior 1st          object
# ...

# %%
corr = train_df.corr()
corr['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice               1.000000
# Overall Qual            0.800028
# Gr Liv Area             0.697032
# Garage Area             0.650097
# Garage Cars             0.648007
# Total Bsmt SF           0.628894
# 1st Flr SF              0.618345
# Bsmt Qual_Ex            0.586529
# Year Built              0.571726
# Kitchen Qual_Ex         0.551320
# Year Remod/Add          0.550142
# Full Bath               0.537913
# TotRms AbvGrd           0.503509
# Mas Vnr Area            0.503417
# Exter Qual_Ex           0.493924
# Fireplaces              0.470740
# Neighborhood_NridgHt    0.448654
# Exter Qual_Gd           0.446408
# BsmtFin SF 1            0.423583
# Fireplace Qu_Gd         0.384488
# Bsmt Exposure_Gd        0.376948
# Lot Frontage            0.342987
# Open Porch SF           0.333123
# Wood Deck SF            0.326365
# Kitchen Qual_Gd         0.306272
# Lot Area                0.296312
# Bsmt Full Bath          0.282880
# Half Bath               0.282595
# ...

# %%
plt.figure(figsize=(16,12))

mask = np.zeros_like(train_df.corr())
#mask 
mask[np.triu_indices_from(mask)] = True

with sns.axes_style("white"):
    ax = sns.heatmap(train_df.corr(),mask=mask, annot=True) 
    ax.set_title("Heatmap of correlation between values", fontsize=25);

# %%
train_df.hist(column='SalePrice')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe8987d6350>]],
#       dtype=object)

# %%
#log transform the target variable for better modeling the relationship between the target and independent variables
target = np.log(train_df['SalePrice'])
sns.distplot(target)

# %% [markdown]
# ## Feature Engineering

# %%
features = ['Overall Qual',
            'Gr Liv Area', 
            'Garage Area', 
            'Garage Cars',
            'Total Bsmt SF',
            '1st Flr SF',
            'Bsmt Qual_Ex',
            'Year Built',
            'Kitchen Qual_Ex',
            'Year Remod/Add',
            'Full Bath',
            'TotRms AbvGrd',
            'Exter Qual_Ex',
            'Fireplaces',
            'Neighborhood_NridgHt',
            'Exter Qual_Gd',
            'Bsmt Qual_TA',
            'Kitchen Qual_TA',
            'Exter Qual_TA']

# %% [markdown]
# Features list
# Overall Qual            0.800028
# Gr Liv Area             0.697032
# Garage Area             0.650097
# Garage Cars             0.648007
# Garage Cars             0.648007
# Total Bsmt SF           0.628894
# 1st Flr SF              0.618345
# Bsmt Qual_Ex            0.586529
# Year Built              0.571726
# Kitchen Qual_Ex         0.551320
# Year Remod/Add          0.550142
# Full Bath               0.537913
# Full Bath               0.537913
# Garage Yr Blt           0.533503
# Mas Vnr Area            0.512071
# TotRms AbvGrd           0.503509
# TotRms AbvGrd           0.503509
# Exter Qual_Ex           0.493924
# Fireplaces              0.470740
# Neighborhood_NridgHt    0.448654
# Exter Qual_Gd           0.446408
# Bsmt Qual_TA           -0.458068
# Kitchen Qual_TA        -0.540939
# Exter Qual_TA          -0.600160
#
# features shortlist for categorical, 'Lot Shape' 'Neighborhood' 'Condition 1' 'Condition 2' 'Roof Matl' 'Bsmt Qual' 'Bsmt Exposure' 'Kitchen Qual' 'Functional' 'Fireplace Qu' 'Overall Qual' 'Garage Cars' 'Bsmt Full Bath' 'Full Bath' 'TotRms AbvGrd' 'Exter Qual' 'Exter Cond'
#
# #combine full bathrooms
#
# #see what can be done about condition 1 and 2 since it is the same ordinal scale, dropping condition 2 since it has low variance that we can try our model on and it is highly collinear with Condition 1.
#
# #might also drop Roof Matl since the distribution is very skewed towards one material.
#
# #We can add 'Gr Liv Area', 'Garage Area', 'Total Bsmt SF', '1st Flr SF ' to our initial shortlist for features. 'Mas Vnr Area' has too many null values for it to be used as a reliable predictor.

# %%
train_df[features].isnull().sum()
# Out:
# Overall Qual            0
# Gr Liv Area             0
# Garage Area             0
# Garage Cars             0
# Total Bsmt SF           0
# 1st Flr SF              0
# Bsmt Qual_Ex            0
# Year Built              0
# Kitchen Qual_Ex         0
# Year Remod/Add          0
# Full Bath               0
# TotRms AbvGrd           0
# Exter Qual_Ex           0
# Fireplaces              0
# Neighborhood_NridgHt    0
# Exter Qual_Gd           0
# Bsmt Qual_TA            0
# Kitchen Qual_TA         0
# Exter Qual_TA           0
# dtype: int64

# %% [markdown]
# ## Modeling

# %%
#Create features matrix (x) and target vector (y)
X = train_df[features]
y = target
X.shape
# Out:
# (2049, 19)

# %%
y.shape
# Out:
# (2049,)

# %%
#baseline score
lr = LinearRegression()
cross_val_score(lr, X, y).mean()
# Out:
# 0.8273245926995101

# %%
#train/test split
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
#scaling for regularization
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.transform(X_test)

# %%
X_train_sc.shape
# Out:
# (1536, 19)

# %%
def get_cv_scores(model):
    scores = cross_val_score(model, X_train_sc, y_train, cv=5, scoring='r2')
    print('CV mean: ', np.mean(scores))
    print('STD: ', np.std(scores))
    print('\n')

# %%
#fitting our model
lr = LinearRegression().fit(X_train_sc, y_train)
get_cv_scores(lr)
# Out:
# CV mean:  0.8197138267407501
# STD:  0.031558355196501055

# %%
#using ridge regularization
ridge = Ridge(alpha=1).fit(X_train_sc, y_train)
get_cv_scores(ridge)
# Out:
# CV mean:  0.8198724342045596
# STD:  0.031200485259704935

# %%
#find optimal alpha with grid search
alpha = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
param_grid = dict(alpha=alpha)

grid = GridSearchCV(estimator=ridge, param_grid=param_grid, scoring='r2', verbose=1, n_jobs=-1)
grid_result = grid.fit(X_train_sc, y_train)

print('Best Score: ', grid_result.best_score_)
print('Best Params: ', grid_result.best_params_)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# Best Score:  0.8205744338116656
# Best Params:  {'alpha': 10}
# [Parallel(n_jobs=-1)]: Done  24 out of  35 | elapsed:    0.9s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    0.9s finished

# %%
#using lasso regularization
lasso = Lasso(alpha=1).fit(X_train_sc, y_train)

get_cv_scores(lasso)
# Out:
# CV mean:  -0.001979484901509165
# STD:  0.001693507576071643

# %%
# find optimal alpha with grid search
alpha = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
param_grid = dict(alpha=alpha)

grid = GridSearchCV(estimator=lasso, param_grid=param_grid, scoring='r2', verbose=1, n_jobs=-1)
grid_result = grid.fit(X_train_sc, y_train)

print('Best Score: ', grid_result.best_score_)
print('Best Params: ', grid_result.best_params_)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# Best Score:  0.8198348203077901
# Best Params:  {'alpha': 0.001}
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    0.1s finished

# %%
#number of coefficients that end up being reduced to zero

col = ['rss','intercept'] + ['coef_x_%d'%i for i in range(1,16)]
ind = ['alpha_%.2g'%alpha[i] for i in range(0,5)]
coef_matrix_lasso = pd.DataFrame(index=ind, columns=col)
coef_matrix_lasso.apply(lambda x: sum(x.values==0),axis=1)
# Out:
# alpha_0.001    0
# alpha_0.01     0
# alpha_0.1      0
# alpha_1        0
# alpha_10       0
# dtype: int64

# %%
corr['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice               1.000000
# Overall Qual            0.800028
# Gr Liv Area             0.697032
# Garage Area             0.650097
# Garage Cars             0.648007
# Total Bsmt SF           0.628894
# 1st Flr SF              0.618345
# Bsmt Qual_Ex            0.586529
# Year Built              0.571726
# Kitchen Qual_Ex         0.551320
# Year Remod/Add          0.550142
# Full Bath               0.537913
# TotRms AbvGrd           0.503509
# Mas Vnr Area            0.503417
# Exter Qual_Ex           0.493924
# Fireplaces              0.470740
# Neighborhood_NridgHt    0.448654
# Exter Qual_Gd           0.446408
# BsmtFin SF 1            0.423583
# Fireplace Qu_Gd         0.384488
# Bsmt Exposure_Gd        0.376948
# Lot Frontage            0.342987
# Open Porch SF           0.333123
# Wood Deck SF            0.326365
# Kitchen Qual_Gd         0.306272
# Lot Area                0.296312
# Bsmt Full Bath          0.282880
# Half Bath               0.282595
# ...

# %%
#let's change the features to include those with 40% or more positive or negative correlation with price
features_40pct_corr = []
for key, value in corr['SalePrice'].items():
    if ((value>=0.40) & (value<0.9)) | (value<=-0.40):
        features_40pct_corr.append(key)
features_40pct_corr
# Out:
# ['Overall Qual',
#  'Year Built',
#  'Year Remod/Add',
#  'Mas Vnr Area',
#  'BsmtFin SF 1',
#  'Total Bsmt SF',
#  '1st Flr SF',
#  'Gr Liv Area',
#  'Full Bath',
#  'TotRms AbvGrd',
#  'Fireplaces',
#  'Garage Cars',
#  'Garage Area',
#  'Neighborhood_NridgHt',
#  'Bsmt Qual_Ex',
#  'Bsmt Qual_TA',
#  'Kitchen Qual_Ex',
#  'Kitchen Qual_TA',
#  'Exter Qual_Ex',
#  'Exter Qual_Gd',
#  'Exter Qual_TA']

# %%
train_df[features_40pct_corr].isnull().sum()
# Out:
# Overall Qual            0
# Year Built              0
# Year Remod/Add          0
# Mas Vnr Area            0
# BsmtFin SF 1            0
# Total Bsmt SF           0
# 1st Flr SF              0
# Gr Liv Area             0
# Full Bath               0
# TotRms AbvGrd           0
# Fireplaces              0
# Garage Cars             0
# Garage Area             0
# Neighborhood_NridgHt    0
# Bsmt Qual_Ex            0
# Bsmt Qual_TA            0
# Kitchen Qual_Ex         0
# Kitchen Qual_TA         0
# Exter Qual_Ex           0
# Exter Qual_Gd           0
# Exter Qual_TA           0
# dtype: int64

# %%
train_df.shape
# Out:
# (2049, 147)

# %%
X = train_df[features_40pct_corr]
y = target
X.shape
# Out:
# (2049, 21)

# %%
y.shape
# Out:
# (2049,)

# %%
#baseline score
lr = LinearRegression()
cross_val_score(lr, X, y).mean()
# Out:
# 0.8301306101131665

# %%
#train/test split
X_train, X_test, y_train, y_test = train_test_split(X,y)
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.transform(X_test)
X_train_sc.shape
# Out:
# (1536, 21)

# %%
lr = LinearRegression().fit(X_train_sc, y_train)
get_cv_scores(lr)
# Out:
# CV mean:  0.8236834558157525
# STD:  0.05342964799085672

# %%
ridge = Ridge(alpha=1).fit(X_train_sc, y_train)
get_cv_scores(ridge)
# Out:
# CV mean:  0.8237652775707911
# STD:  0.05334304966492861

# %%
#find optimal alpha with grid search
alpha = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
param_grid = dict(alpha=alpha)

grid = GridSearchCV(estimator=ridge, param_grid=param_grid, scoring='r2', verbose=1, n_jobs=-1)
grid_result = grid.fit(X_train_sc, y_train)

print('Best Score: ', grid_result.best_score_)
print('Best Params: ', grid_result.best_params_)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# Best Score:  0.8249003175774183
# Best Params:  {'alpha': 100}
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    0.1s finished

# %%
y_train_rdg = ridge.predict(X_train)
y_test_rdg = ridge.predict(X_test)

# Plot residuals
plt.scatter(y_train_rdg, y_train_rdg - y_train, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_rdg, y_test_rdg - y_test, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression with Ridge regularization")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.legend(loc = "upper left")
plt.hlines(y = 0, xmin = 10.5, xmax = 13.5, color = "red")
plt.show()

# Plot predictions
plt.scatter(y_train_rdg, y_train, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_rdg, y_test, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression with Ridge regularization")
plt.xlabel("Predicted values")
plt.ylabel("Real values")
plt.legend(loc = "upper left")
plt.plot([10.5, 13.5], [10.5, 13.5], c = "red")
plt.show()

# Plot important coefficients
coefs = pd.Series(ridge.coef_, index = X_train.columns)
print("Ridge picked " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")
imp_coefs = pd.concat([coefs.sort_values().head(10),
                     coefs.sort_values().tail(10)])
imp_coefs.plot(kind = "barh")
plt.title("Coefficients in the Ridge Model")
plt.show()
# Out:
# Ridge picked 21 features and eliminated the other 0 features

# %%
lasso = Lasso(alpha=1).fit(X_train_sc, y_train)
get_cv_scores(lasso)
# Out:
# CV mean:  -0.00520610651597897
# STD:  0.007114191683134591

# %%
# find optimal alpha with grid search
alpha = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
param_grid = dict(alpha=alpha)

grid = GridSearchCV(estimator=lasso, param_grid=param_grid, scoring='r2', verbose=1, n_jobs=-1)
grid_result = grid.fit(X_train_sc, y_train)

print('Best Score: ', grid_result.best_score_)
print('Best Params: ', grid_result.best_params_)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# Best Score:  0.8240882380848686
# Best Params:  {'alpha': 0.001}
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    0.1s finished

# %%
#number of coefficients that end up being reduced to zero

col = ['rss','intercept'] + ['coef_x_%d'%i for i in range(1,16)]
ind = ['alpha_%.2g'%alpha[i] for i in range(0,5)]
coef_matrix_lasso = pd.DataFrame(index=ind, columns=col)
coef_matrix_lasso.apply(lambda x: sum(x.values==0),axis=1)
# Out:
# alpha_0.001    0
# alpha_0.01     0
# alpha_0.1      0
# alpha_1        0
# alpha_10       0
# dtype: int64

# %%
y_train_las = lasso.predict(X_train_sc)
y_test_las = lasso.predict(X_test)

# Plot residuals
plt.scatter(y_train_las, y_train_las - y_train, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_las, y_test_las - y_test, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression with Lasso regularization")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.legend(loc = "upper left")
plt.hlines(y = 0, xmin = 10.5, xmax = 13.5, color = "red")
plt.show()

# Plot predictions
plt.scatter(y_train_las, y_train, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_las, y_test, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression with Lasso regularization")
plt.xlabel("Predicted values")
plt.ylabel("Real values")
plt.legend(loc = "upper left")
plt.plot([10.5, 13.5], [10.5, 13.5], c = "red")
plt.show()

# Plot important coefficients
coefs = pd.Series(lasso.coef_, index = X_train_sc.columns)
print("Lasso picked " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")
imp_coefs = pd.concat([coefs.sort_values().head(10),
                     coefs.sort_values().tail(10)])
imp_coefs.plot(kind = "barh")
plt.title("Coefficients in the Lasso Model")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-c77ae0fc20fe> in <module>
#      23
#      24 # Plot important coefficients
# ---> 25 coefs = pd.Series(lasso.coef_, index = X_train_sc.columns)
#      26 print("Lasso picked " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
#      27       str(sum(coefs == 0)) + " features")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
#let's see how our model does on unseen data
#matching get_dummies

# %%
#matching the test data and doing a prediction

# %%
#pred = pd.DataFrame(y_pred)
#sub_df = pd.read_csv('../datasets/sample_sub_reg.csv')
#datasets = pd.concat([sub_df['Id'], pred], axis=1)
#datasets.columns = ['Id', 'SalePrice']
#datasets.to_csv('../datasets/sample_sub_reg.csv', index=True)
